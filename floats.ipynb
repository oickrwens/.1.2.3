# %%
import math
>>> math.fsum([.1,.2,-.3,-.1])
# Out:
# -0.09999999999999998

# %%
import numpy as np
np.sum([.1,.2,-.3,-.1])
# Out:
# -0.09999999999999995

# %%
print(np.sum([.1,.2, -.3], dtype=np.float32))
print(np.sum([.1,.2,-.3], dtype=np.float64))
print(np.sum([.1,.2,-.3], dtype=np.float128))
# Out:
# 0.0
# 5.551115123125783e-17
# 2.775557561562891351e-17

# %%
import pandas as pd
pd.Series([.1,.2,-.3]).sum()
# Out:
# 5.551115123125783e-17

# %%
import scipy
scipy.sum([.1,.2,-.3])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
# 5.551115123125783e-17
